# %%
import pandas as pd
import numpy as np
df = pd.read_csv("placement_data.csv")
print(df)
# Out:
#      Name  Department  CGPA Internship Placed  Package_LPA
# 0    Aman  Mechanical   8.5        Yes    Yes            8
# 1   Priya    Computer   9.2        Yes    Yes           15
# 2   Rahul  Mechanical   7.1         No     No            0
# 3   Sneha  Electrical   8.9        Yes    Yes           10
# 4   Karan       Civil   6.8         No     No            0
# 5    Neha    Computer   8.1        Yes    Yes           12
# 6   Vikas  Mechanical   7.8        Yes    Yes            7
# 7   Pooja  Electrical   7.3         No    Yes            6
# 8   Rohit       Civil   8.0        Yes    Yes            9
# 9  Anjali    Computer   9.5        Yes    Yes           18
